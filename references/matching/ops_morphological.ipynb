# %%
import matplotlib.pyplot as plt

def display(matrix, title=None, figsize=(8, 8)):
    fig, ax = plt.subplots(figsize=figsize)
    ax.imshow(matrix, cmap="Paired", vmin=0, vmax=12)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(j, i, matrix[i, j], ha="center", va="center", color="w")
    ax.set_title(title)
    #ax.set_axis_off()
    plt.show()

# %%
import cv2 as cv
import numpy as np
from skimage.morphology import disk
from morphology import binary_closing, binary_opening, binary_dilate, binary_erode

# %%
templ = np.zeros((30, 30), np.uint8)
#templ[10:21, 10:21] = disk(5)
#templ[10:21, 10:21] = 1

templ[0:15, 0:30] = 1
templ[6:15, 9:21] = 0
templ[13:15, 21:30] = 0

display(templ, "ori")

# %% [markdown]
# # Morphological - disk

# %%
radius = 3
kernel = disk(radius=radius)
for func in [binary_closing, binary_opening, binary_dilate, binary_erode]:
    val = func(templ, kernel)
    display(val, func.__name__)
    print((val * 1.0 - templ).sum())
# Out:
# 10.0
# -10.0
# 128.0
# -128.0

# %% [markdown]
# # Morphological - square

# %%
radius = 3
ksize = radius * 2 + 1
kernel = np.ones((ksize, ksize), np.uint8)
for func in [binary_closing, binary_opening, binary_dilate, binary_erode]:
    val = func(templ, kernel)
    display(val, func.__name__)
    print((val * 1.0 - templ).sum())
# Out:
# 0.0
# 0.0
# 138.0
# -138.0
